# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
import os
from importlib import reload

sys.path.append(os.path.abspath(".."))

import src.linear_regression
reload(src.linear_regression)

from src.linear_regression import LinearRegression
from src.scaler import StandardScaler
from sklearn.linear_model import LinearRegression as sklearnLR
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.isnull().value_counts()
# Out:
# TV     Radio  Newspaper  Sales
# False  False  False      False    200
# Name: count, dtype: int64

# %%
X = df[["TV", "Radio", "Newspaper"]].values
y = df["Sales"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression(lr = 0.00003, iterations=1000000)
model.fit(X_train, y_train)
# Out:
# Iteration 0: Loss = 255.92093750000004
# Iteration 1000: Loss = 5.656961006627027
# Iteration 2000: Loss = 5.606184854576432
# Iteration 3000: Loss = 5.556237003214231
# Iteration 4000: Loss = 5.507103939820414
# Iteration 5000: Loss = 5.458772372943697
# Iteration 6000: Loss = 5.41122922795322
# Iteration 7000: Loss = 5.364461643501608
# Iteration 8000: Loss = 5.3184569680457265
# Iteration 9000: Loss = 5.273202756424201
# Iteration 10000: Loss = 5.228686766490745
# Iteration 11000: Loss = 5.1848969558024365
# Iteration 12000: Loss = 5.141821478361976
# Iteration 13000: Loss = 5.099448681413148
# Iteration 14000: Loss = 5.057767102288496
# Iteration 15000: Loss = 5.01676546530846
# Iteration 16000: Loss = 4.9764326787310855
# Iteration 17000: Loss = 4.936757831751482
# Iteration 18000: Loss = 4.897730191550249
# Iteration 19000: Loss = 4.859339200390029
# Iteration 20000: Loss = 4.821574472759451
# Iteration 21000: Loss = 4.78442579256362
# Iteration 22000: Loss = 4.747883110360485
# ...

# %%
sklearn_model = sklearnLR()
sklearn_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Linear Regression from scratch:")
print("Train R²:", model.score(X_train, y_train))
print("Test R²:", model.score(X_test, y_test))
print(f" ")
print(f"Linear Regression from scikit-learn:")
print("Train R²:", sklearn_model.score(X_train, y_train))
print("Test R²:", sklearn_model.score(X_test, y_test))
# Out:
# Linear Regression from scratch:
# Train R²: 0.9041008277293628
# Test R²: 0.8937301763464361
#
# Linear Regression from scikit-learn:
# Train R²: 0.9041008363106763
# Test R²: 0.8937195243944447

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model_v2 = LinearRegression(lr = 0.00003, iterations=1000000)
model_v2.fit(X_train_scaled, y_train)
# Out:
# Iteration 0: Loss = 255.92093750000004
# Iteration 1000: Loss = 227.22416616773754
# Iteration 2000: Loss = 201.78169228412872
# Iteration 3000: Loss = 179.22394366265374
# Iteration 4000: Loss = 159.2233890887477
# Iteration 5000: Loss = 141.48974597858688
# Iteration 6000: Loss = 125.76573575632811
# Iteration 7000: Loss = 111.82332414292219
# Iteration 8000: Loss = 99.46039078208256
# Iteration 9000: Loss = 88.49777902415931
# Iteration 10000: Loss = 78.7766823441332
# Iteration 11000: Loss = 70.15632887179387
# Iteration 12000: Loss = 62.51192993645134
# Iteration 13000: Loss = 55.73286244230524
# Iteration 14000: Loss = 49.72105835314123
# Iteration 15000: Loss = 44.389577628652006
# Iteration 16000: Loss = 39.661343665575984
# Iteration 17000: Loss = 35.46802269589003
# Iteration 18000: Loss = 31.749030717472593
# Iteration 19000: Loss = 28.450653411908263
# Iteration 20000: Loss = 25.52526616755126
# Iteration 21000: Loss = 22.930642798517866
# ...
